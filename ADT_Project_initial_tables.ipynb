# %%
import pandas as pd

# %%
# !pip install pymongo
# !pip3 install 'pymongo[srv]'
# Out:
# ...
# ERROR: Invalid requirement: "'pymongo[srv]'"

# %%
df = pd.read_excel('C:\\Users\\Venka\\Downloads\\initialdata.xlsx')

# %%
df
# Out:
#     Customer Id First name Middle Name Last name                   Email-Id  \
# 0             1       John         NaN      Smith       johnsmith@gmail.com
# 1             2      Emily       Grace    Johnson         emily.j@gmail.com
# 2             3    Michael         NaN      Davis          mdavis@gmail.com
# 3             4      Sarah        Anne     Miller     sarahmiller@gmail.com
# 4             5      David         NaN     Wilson         dwilson@gmail.com
# ..          ...        ...         ...        ...                       ...
# 95           96        Eli         Lee     Bowers      eli.bowers@gmail.com
# 96           97     Stella         NaN    Mendoza  stella.mendoza@gmail.com
# 97           98        Max       James     Norman      max.norman@gmail.com
# 98           99        Ivy        Anne        Ray         ivy.ray@gmail.com
# 99          100     Oliver       Grace     Barber   oliver.barber@gmail.com
#
# ...

# %% [markdown]
# ### Splitting the initial data into two tables(Customer and Restaurant)

# %%
customer = df.iloc[:, :-5]  
restaurant = df.iloc[:, -5:]

# %%
customer
# Out:
#     Customer Id First name Middle Name Last name                   Email-Id  \
# 0             1       John         NaN      Smith       johnsmith@gmail.com
# 1             2      Emily       Grace    Johnson         emily.j@gmail.com
# 2             3    Michael         NaN      Davis          mdavis@gmail.com
# 3             4      Sarah        Anne     Miller     sarahmiller@gmail.com
# 4             5      David         NaN     Wilson         dwilson@gmail.com
# ..          ...        ...         ...        ...                       ...
# 95           96        Eli         Lee     Bowers      eli.bowers@gmail.com
# 96           97     Stella         NaN    Mendoza  stella.mendoza@gmail.com
# 97           98        Max       James     Norman      max.norman@gmail.com
# 98           99        Ivy        Anne        Ray         ivy.ray@gmail.com
# 99          100     Oliver       Grace     Barber   oliver.barber@gmail.com
#
# ...

# %%
restaurant
# Out:
#         Resturant_name                      Resturant_Address  \
# 0        Spice Delight    123 Main Street, Cityville, Indiana
# 1         Bella Italia     456 Oak Avenue, Townsville,Indiana
# 2   Sizzling Sushi Bar    789 Elm Street, Villageton, Indiana
# 3       The Green Fork    321 Maple Drive, Riverside, Indiana
# 4   Fire & Spice Grill        567 Pine Lane, Hilltop, Indiana
# ..                 ...                                    ...
# 95  Sizzling Sushi Bar    789 Elm Street, Villageton, Indiana
# 96  Fire & Spice Grill        567 Pine Lane, Hilltop, Indiana
# 97       Spice Delight    123 Main Street, Cityville, Indiana
# 98        Indian Taste  234 Curry Street, Masalatown, Indiana
# 99        Bella Italia     456 Oak Avenue, Townsville,Indiana
#
#                     Resturant_email         Login_id       Password
# 0            spicedelight@email.com  spicedelight123        SD#4567
# 1    bellaitalia@restaurantmail.com   bellaitalia123    Italia$1234
# ...

# %% [markdown]
# ### Creating collections and inserting the data from the Dataframe

# %%
import pymongo
client = pymongo.MongoClient("mongodb+srv://vmunnang:root0301@resturantend.fvcfjva.mongodb.net/")
db = client["Redturant_End"]
collection = db["Customer"]
data = customer.to_dict(orient='records')
collection.insert_many(data)
# Out:
# InsertManyResult([ObjectId('6612ee18d5f990ed99afa894'), ObjectId('6612ee18d5f990ed99afa895'), ObjectId('6612ee18d5f990ed99afa896'), ObjectId('6612ee18d5f990ed99afa897'), ObjectId('6612ee18d5f990ed99afa898'), ObjectId('6612ee18d5f990ed99afa899'), ObjectId('6612ee18d5f990ed99afa89a'), ObjectId('6612ee18d5f990ed99afa89b'), ObjectId('6612ee18d5f990ed99afa89c'), ObjectId('6612ee18d5f990ed99afa89d'), ObjectId('6612ee18d5f990ed99afa89e'), ObjectId('6612ee18d5f990ed99afa89f'), ObjectId('6612ee18d5f990ed99afa8a0'), ObjectId('6612ee18d5f990ed99afa8a1'), ObjectId('6612ee18d5f990ed99afa8a2'), ObjectId('6612ee18d5f990ed99afa8a3'), ObjectId('6612ee18d5f990ed99afa8a4'), ObjectId('6612ee18d5f990ed99afa8a5'), ObjectId('6612ee18d5f990ed99afa8a6'), ObjectId('6612ee18d5f990ed99afa8a7'), ObjectId('6612ee18d5f990ed99afa8a8'), ObjectId('6612ee18d5f990ed99afa8a9'), ObjectId('6612ee18d5f990ed99afa8aa'), ObjectId('6612ee18d5f990ed99afa8ab'), ObjectId('6612ee18d5f990ed99afa8ac'), ObjectId('6612ee18d5f990ed99af
# ...

# %%
collection_login = db["User_Auth"]
data = restaurant.to_dict(orient='records')
collection_login.insert_many(data)
# Out:
# InsertManyResult([ObjectId('6612eeaed5f990ed99afa8f8'), ObjectId('6612eeaed5f990ed99afa8f9'), ObjectId('6612eeaed5f990ed99afa8fa'), ObjectId('6612eeaed5f990ed99afa8fb'), ObjectId('6612eeaed5f990ed99afa8fc'), ObjectId('6612eeaed5f990ed99afa8fd'), ObjectId('6612eeaed5f990ed99afa8fe'), ObjectId('6612eeaed5f990ed99afa8ff'), ObjectId('6612eeaed5f990ed99afa900'), ObjectId('6612eeaed5f990ed99afa901'), ObjectId('6612eeaed5f990ed99afa902'), ObjectId('6612eeaed5f990ed99afa903'), ObjectId('6612eeaed5f990ed99afa904'), ObjectId('6612eeaed5f990ed99afa905'), ObjectId('6612eeaed5f990ed99afa906'), ObjectId('6612eeaed5f990ed99afa907'), ObjectId('6612eeaed5f990ed99afa908'), ObjectId('6612eeaed5f990ed99afa909'), ObjectId('6612eeaed5f990ed99afa90a'), ObjectId('6612eeaed5f990ed99afa90b'), ObjectId('6612eeaed5f990ed99afa90c'), ObjectId('6612eeaed5f990ed99afa90d'), ObjectId('6612eeaed5f990ed99afa90e'), ObjectId('6612eeaed5f990ed99afa90f'), ObjectId('6612eeaed5f990ed99afa910'), ObjectId('6612eeaed5f990ed99af
# ...

# %% [markdown]
# ### Customers Who are from Bloomington

# %%
bloomington_customers = db.Customer.count_documents({'City': "Bloomington"})
print(bloomington_customers)
# Out:
# 87

# %% [markdown]
# ### People with spice level preference with 'Less spicy'

# %%
result = collection.find({"Preference_Spice level": "Less Spicy"}) 
df = pd.DataFrame(list(result))
df
# Out:
#                          _id  Customer Id   First name Middle Name  \
# 0   6612ee18d5f990ed99afa894            1         John         NaN
# 1   6612ee18d5f990ed99afa897            4        Sarah        Anne
# 2   6612ee18d5f990ed99afa89a            7  Christopher         NaN
# 3   6612ee18d5f990ed99afa8a0           13       Justin         NaN
# 4   6612ee18d5f990ed99afa8a3           16        Megan        Rose
# 5   6612ee18d5f990ed99afa8a6           19      Brandon         NaN
# 6   6612ee18d5f990ed99afa8a9           22     Samantha         NaN
# 7   6612ee18d5f990ed99afa8ac           25      Timothy         NaN
# 8   6612ee18d5f990ed99afa8b1           30       Rachel        Anne
# 9   6612ee18d5f990ed99afa8b4           33        Logan         NaN
# 10  6612ee18d5f990ed99afa8b7           36       Morgan         NaN
# 11  6612ee18d5f990ed99afa8b8           37      Abigail       Marie
# 12  6612ee18d5f990ed99afa8be           43          Zoe        Anne
# ...

# %% [markdown]
# ### People who are not allergic to anything

# %%
result = collection.find({"Customer_allergic to": "No Preference"}) 
df = pd.DataFrame(list(result))
df
# Out:
#                          _id  Customer Id First name Middle Name Last name   \
# 0   6612ee18d5f990ed99afa89f           12     Ashley      Nicole       Hall
# 1   6612ee18d5f990ed99afa8a1           14  Stephanie         Ann     Carter
# 2   6612ee18d5f990ed99afa8a3           16      Megan        Rose     Martin
# 3   6612ee18d5f990ed99afa8a4           17      Kevin         NaN      Perez
# 4   6612ee18d5f990ed99afa8a5           18   Jennifer       Marie      Lewis
# ..                       ...          ...        ...         ...        ...
# 59  6612ee18d5f990ed99afa8ef           92    Lincoln         NaN     Reeves
# 60  6612ee18d5f990ed99afa8f0           93      Hazel       James      Greer
# 61  6612ee18d5f990ed99afa8f3           96        Eli         Lee     Bowers
# 62  6612ee18d5f990ed99afa8f4           97     Stella         NaN    Mendoza
# 63  6612ee18d5f990ed99afa8f6           99        Ivy        Anne        Ray
#
# ...

# %% [markdown]
# ### Number of customers with both cooking level for meat and cooking oil preference as "No Preference"

# %%
result = db.Customer.count_documents({"Preference_cooking level for meat":"No Preference","Preference_Cooking oil":"No Preference"}) 
#df = pd.DataFrame(list(result))
#df
print(result)
# Out:
# 4

# %% [markdown]
# ### Customers who have some kind of preference in their preference notes

# %%
result = collection.find({"Preference_notes": {"$exists": True, "$ne": "No Preference"}})
df = pd.DataFrame(list(result))
df
# Out:
#                          _id  Customer Id   First name Middle Name  \
# 0   6612ee18d5f990ed99afa894            1         John         NaN
# 1   6612ee18d5f990ed99afa897            4        Sarah        Anne
# 2   6612ee18d5f990ed99afa89a            7  Christopher         NaN
# 3   6612ee18d5f990ed99afa8a2           15     Nicholas         NaN
# 4   6612ee18d5f990ed99afa8a4           17        Kevin         NaN
# 5   6612ee18d5f990ed99afa8ac           25      Timothy         NaN
# 6   6612ee18d5f990ed99afa8af           28     Victoria        Lynn
# 7   6612ee18d5f990ed99afa8b0           29        Caleb         NaN
# 8   6612ee18d5f990ed99afa8b4           33        Logan         NaN
# 9   6612ee18d5f990ed99afa8ba           39       Hailey       Grace
# 10  6612ee18d5f990ed99afa8bf           44        Mason         NaN
# 11  6612ee18d5f990ed99afa8c8           53       Aurora         NaN
# 12  6612ee18d5f990ed99afa8d0           61      Gabriel         NaN
# ...
